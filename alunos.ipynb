# %%
import pandas as pd

tabela = pd.read_excel("tabela_alunos.xlsx")
display(tabela)
# Out:
#                                   Nome Atividade       Data      Hora
# 0        Maria Luiza Camargo Gonçalves    Entrou 2023-08-24  18:38:00
# 1              Izaura dos Santos Souza    Entrou 2023-08-24  18:38:00
# 2         William Lourenço de Oliveira    Entrou 2023-08-24  18:38:00
# 3          Fernando Marques dos Santos    Entrou 2023-08-24  18:38:00
# 4              Felipe de Souza Freitas    Entrou 2023-08-24  18:38:00
# 5              Felipe de Souza Freitas      Saiu 2023-08-24  19:59:00
# 6              Felipe de Souza Freitas    Entrou 2023-08-24  20:01:00
# 7                  Rayssa Barros Alves    Entrou 2023-08-24  18:38:00
# 8   Carolina Aparecida Henriques Prado    Entrou 2023-08-24  18:38:00
# 9          Cauan Menezes de Matos Luiz    Entrou 2023-08-24  18:38:00
# 10         Cauan Menezes de Matos Luiz      Saiu 2023-08-24  19:22:00
# 11         Cauan Menezes de Matos Luiz    Entrou 2023-08-24  19:22:00
# ...

# %%
import matplotlib.pyplot as plt
 
tabela_alunos = tabela["Atividade"]

plt.title("Atividade dos alunos durante a aula-24/08/2023.")
plt.plot(tabela_alunos, marker="o", linestyle="solid", color="black")
plt.grid()
plt.show()

# %%
import pandas as pd


data = {
    'Nome': [
        'Maria Luiza Camargo Gonçalves', 'Izaura dos Santos Souza', 'William Lourenço de Oliveira',
        'Fernando Marques dos Santos', 'Felipe de Souza Freitas', 'Felipe de Souza Freitas',
        'Felipe de Souza Freitas', 'Rayssa Barros Alves', 'Carolina Aparecida Henriques Prado',
        'Cauan Menezes de Matos Luiz', 'Cauan Menezes de Matos Luiz', 'Cauan Menezes de Matos Luiz',
        'Hyago Martinez Rubo', 'Kaique Donizeti da Silva', 'Maria Elyza Andrade Silva',
        'Maria Elyza Andrade Silva', 'Thiago Cauan de Lima Santos', 'Beatriz Lemos Soares'
    ],
    'Atividade': [
        'Entrou', 'Entrou', 'Entrou', 'Entrou', 'Entrou', 'Saiu', 'Entrou', 'Entrou',
        'Entrou', 'Entrou', 'Saiu', 'Entrou', 'Entrou', 'Entrou', 'Entrou', 'Saiu', 'Entrou', 'Entrou'
    ],
    'Data': [
        '24/08/2023', '24/08/2023', '24/08/2023', '24/08/2023', '24/08/2023', '24/08/2023',
        '24/08/2023', '24/08/2023', '24/08/2023', '24/08/2023', '24/08/2023', '24/08/2023',
        '24/08/2023', '24/08/2023', '24/08/2023', '24/08/2023', '24/08/2023', '24/08/2023'
    ],
    'Hora': [
        '18:38', '18:38', '18:38', '18:38', '18:38', '19:59', '20:01', '18:38', '18:38',
        '18:38', '19:22', '19:22', '18:38', '18:38', '18:38', '20:16', '18:38', '18:38'
    ]
}


df = pd.DataFrame(data)

alunos_off = df[df['Atividade'] == 'Saiu']['Nome'].nunique()

print(f"A quantidade de alunos que cairam duarante a trasnmissão foram: {alunos_off}")
# Out:
# A quantidade de alunos que cairam duarante a trasnmissão foram: 3
